# %%
import pycaret
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset_dir = "D:\Digant\Codes\Machine Learning\Datasets\creditcardfraud\creditcard.csv"
df = pd.read_csv(dataset_dir)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
len(df[df['Class']==0])
# Out:
# 284315

# %%
len(df[df['Class']==1])
# Out:
# 492

# %%
from pycaret.classification import *

# %%
setup  = setup(data=df,target='Class')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_bb345382_86e3_11ea_9f45_3c95098e6396" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bb345382_86e3_11ea_9f45_3c95098e6396level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bb345382_86e3_11ea_9f45_3c95098e6396row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_bb345382_86e3_11ea_9f45_3c95098e6396row0_col1" class="data row0 col1" >4762</td>
#             </tr>
#             <tr>
#                         <th id="T_bb345382_86e3_11ea_9f45_3c95098e6396level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bb345382_86e3_11ea_9f45_3c95098e6396row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396 th {
#           text-align: left;
#     }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col0 {
#             text-align:  left;
#         }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ad8fa526_86fc_11ea_b6cc_3c95098e6396row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...
